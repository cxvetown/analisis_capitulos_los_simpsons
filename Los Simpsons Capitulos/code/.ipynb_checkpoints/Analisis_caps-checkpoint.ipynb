# %%
#importamos las librerias
import pandas as pd #manipulación y análisis de datos
import numpy as np #soporte para crear vectores y matrices grandes multidimensionales
import seaborn as sb #biblioteca de visualización de datos de Python
import matplotlib.pyplot as plt #biblioteca de visualización de datos de Python
import re #Expresiones regulares
import os

import seaborn as sns
import matplotlib.pyplot as plt

# %%
mainpath = "../dataset/"
filename = "imdb_simpsons_dataset.csv"
fullpath = os.path.join(mainpath, filename)

# %%
#Se utiliza la función .read_csv de la librería pandas para leer el dataset, luego este es asignado a la variable dataframe 'df'
df = pd.read_csv(fullpath, encoding='utf-8')

# %%
df.head()
# Out:
#    episode_no_abs  season_no  episode_no                       episode_name  \
# 0               1          1           1  Simpsons Roasting on an Open Fire
# 1               2          1           2                    Bart the Genius
# 2               3          1           3                    Homer's Odyssey
# 3               4          1           4      There's No Disgrace Like Home
# 4               5          1           5                   Bart the General
#
#   episode_airdate  episode_score  episode_votes  \
# 0        2-Sep-90            8.2           6953
# 1       14-Jan-90            7.7           4557
# 2       21-Jan-90            7.4           4007
# 3       28-Jan-90            7.7           3955
# 4        4-Feb-90            8.0           4299
#
#                                  episode_description
# 0  Homer is forced to become a department store S...
# 1  Bart ends up at a school for gifted children a...
# 2  After losing his job, Homer contemplates endin...
# 3  After being embarrassed by the rest of the fam...
# 4  After being beaten up by Nelson Muntz one too ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   episode_no_abs       705 non-null    int64
#  1   season_no            705 non-null    int64
#  2   episode_no           705 non-null    int64
#  3   episode_name         705 non-null    object
#  4   episode_airdate      705 non-null    object
#  5   episode_score        705 non-null    float64
#  6   episode_votes        705 non-null    int64
#  7   episode_description  705 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 44.2+ KB

# %%
df['episode_airdate'] = pd.to_datetime(df['episode_airdate'])
df['episode_score'] = df['episode_score'].astype(float)
df['episode_votes'] = df['episode_votes'].astype(int)

# %%
#se agrupan en el puntaje IMDB de cada capitulo
df_desc = df.groupby('season_no')['episode_score'].describe().round(1)
df_desc = df_desc[['mean', 'std', 'min', 'max']].reset_index()
df_desc
# Out:
#     season_no  mean  std  min  max
# 0           1   7.8  0.3  7.4  8.4
# 1           2   8.0  0.4  7.4  8.8
# 2           3   8.2  0.3  7.6  8.8
# 3           4   8.3  0.5  7.0  9.1
# 4           5   8.4  0.4  7.5  9.2
# 5           6   8.4  0.7  5.8  9.2
# 6           7   8.4  0.4  7.5  9.1
# 7           8   8.3  0.5  7.2  9.3
# 8           9   7.8  0.7  5.0  9.1
# 9          10   7.6  0.4  7.0  8.2
# 10         11   7.3  0.4  6.4  8.0
# 11         12   7.3  0.5  6.6  8.6
# 12         13   7.1  0.5  5.4  7.8
# 13         14   7.0  0.3  6.6  7.7
# 14         15   7.0  0.3  6.3  7.6
# 15         16   6.9  0.3  6.2  7.5
# 16         17   6.8  0.4  6.1  7.7
# 17         18   6.9  0.5  5.9  8.1
# 18         19   6.9  0.5  6.0  8.2
# 19         20   6.9  0.4  6.0  7.3
# 20         21   6.8  0.4  5.7  7.4
# 21         22   6.7  0.4  6.0  7.2
# 22         23   6.7  0.9  3.9  8.3
# 23         24   6.7  0.4  6.1  7.3
# 24         25   6.7  0.5  5.8  7.9
# 25         26   6.6  0.5  5.6  7.9
# 26         27   6.7  0.6  5.6  8.5
# 27         28   6.5  0.3  6.0  7.1
# 28         29   6.7  0.4  6.1  7.7
# 29         30   6.2  0.6  4.6  7.1
# 30         31   6.5  0.5  5.6  7.6
# 31         32   6.5  0.5  5.7  7.8

# %%
fig, ax = plt.subplots()
ax.plot(df_desc['season_no'], df_desc['mean'], marker = 'o', color = 'tab:red')

ax.set_title('Puntaje promedio de cada temporada', fontdict = {'fontsize':14, 'fontweight':'bold'})
ax.set_xlabel("Temporadas")
ax.set_ylabel("Puntaje")

plt.show()

# %%
df_desc_votation = df.groupby('season_no')['episode_votes'].describe().round(1)
df_desc_votation = df_desc_votation[['mean', 'std', 'min', 'max']].reset_index()
df_desc_votation
# Out:
#     season_no    mean    std     min     max
# 0           1  4090.2  915.8  3443.0  6953.0
# 1           2  3298.2  448.0  2769.0  4145.0
# 2           3  3013.8  423.9  2566.0  4113.0
# 3           4  3044.8  611.1  2405.0  4612.0
# 4           5  2930.5  530.1  2235.0  4576.0
# 5           6  2830.6  506.9  2272.0  4079.0
# 6           7  2710.0  478.7  2102.0  3763.0
# 7           8  2791.6  894.9  2040.0  5413.0
# 8           9  2240.4  479.6  1855.0  4185.0
# 9          10  1902.7  208.6  1630.0  2423.0
# 10         11  1702.8  176.8  1543.0  2231.0
# 11         12  1715.9  241.9  1434.0  2383.0
# 12         13  1511.0  189.1  1308.0  1970.0
# 13         14  1400.5  158.1  1215.0  1921.0
# 14         15  1334.0   91.6  1244.0  1677.0
# 15         16  1280.1   87.4  1180.0  1567.0
# 16         17  1303.4   98.3  1198.0  1550.0
# 17         18  1365.5  204.2  1188.0  2178.0
# 18         19  1364.0  203.2  1140.0  1940.0
# 19         20  1276.1  105.5  1152.0  1535.0
# 20         21  1151.3  105.9  1024.0  1425.0
# 21         22  1096.5   91.2   987.0  1370.0
# 22         23  1250.2  409.7   925.0  2793.0
# 23         24   994.3   96.7   879.0  1301.0
# 24         25  1080.4  170.5   940.0  1586.0
# 25         26  1015.4  249.0   819.0  1931.0
# 26         27   947.7  261.6   748.0  1925.0
# 27         28   784.9   92.8   681.0  1038.0
# 28         29   813.7  136.1   660.0  1141.0
# 29         30   766.6  159.3   609.0  1334.0
# 30         31   681.2  124.0   524.0   910.0
# 31         32   552.6  132.6   354.0   908.0

# %%
fig, ax = plt.subplots()
ax.fill_between(df_desc_votation['season_no'], df_desc_votation['mean'], color = 'tab:purple')
ax.set_title('Votaciones promedio de cada temporada', fontdict = {'fontsize':14, 'fontweight':'bold'})
ax.set_xlabel("Temporadas")
ax.set_ylabel("Votaciones")
plt.show()
